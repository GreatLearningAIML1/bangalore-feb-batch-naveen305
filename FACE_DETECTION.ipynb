# %% [markdown]
# #### In this problem we use "Transfer Learning" of an Object Detector model to detect any object according to the problem in hand.
#
# Here, We are particularly interested in detecting faces in a given image.
#
# #### To use the model first, we need to import the model and its supporting files for the model to function.
#
# We see the below steps to import the model.

# %% [markdown]
# ### Import MobileNet model given in file `mn_model.py`

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# dataset/                         Models/
# _DS_Store                        output_test/
# face_generator.py                predictor.py
# face_generator.pyc               ssd_box_encode_decode_utils.py
# _gitattributes                   ssd_box_encode_decode_utils.pyc
# _gitignore                       ssd_mobilenet_face_epoch_25_loss0.0916.h5
# keras_layer_AnchorBoxes.py       wider_extract.py
# keras_layer_AnchorBoxes.pyc      WIDER_train/
# keras_layer_L2Normalization.py   wider_train_small.npy
# keras_layer_L2Normalization.pyc  wider_train_v1.npy
# keras_ssd_loss.py                WIDER_train.zip
# keras_ssd_loss.pyc               WIDER_val/
# mn_model.py                      wider_val_small.npy
# mn_model.pyc                     wider_val_v1.npy
# mobilenet_1_0_224_tf.h5          WIDER_val.zip

# %%
os.chdir('/content/drive/My Drive/Face Detection/')

# %%
pwd
# Out:
# u'/content/drive/My Drive/Face Detection'

# %%
### Import MobileNet model given in file `mn_model.py`

from mn_model import mn_model

# %% [markdown]
# ### Import the BatchGenerator and SSDLoss functions in given files `face_generator.py`, `keras_ssd_loss` and `ssd_box_encode_decode_utils.py` as well, used in MobileNet model

# %%
#### Import the BatchGenerator and SSDLoss functions as well, used in MobileNet model

from face_generator import BatchGenerator
from keras_ssd_loss import SSDLoss
from ssd_box_encode_decode_utils import SSDBoxEncoder, decode_y, decode_y2

# %%
import warnings
warnings.filterwarnings("ignore")

from keras.optimizers import Adam, SGD, Nadam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard, LearningRateScheduler
from keras.callbacks import Callback
from keras import backend as K 
from keras.models import load_model
from math import ceil 
import numpy as np 
from termcolor import colored

from mn_model import mn_model
from face_generator import BatchGenerator
from keras_ssd_loss import SSDLoss
from ssd_box_encode_decode_utils import SSDBoxEncoder, decode_y, decode_y2

# training parameters
from keras import backend as K
import scipy.misc as sm

# %% [markdown]
# ## Set the parameters for the model
#
# #### We need to customize the model parameters according to our problem as given below.
#
# #### Set n_classes (no.of classes) = 2, as we are interested in only face detection.
# #### `Face` will be one class and everything else comes under other class (we can call it as `background`)
#
# #### Set class_names = ["background", "face"]

# %%
img_height =512
img_width = 512

img_channels = 3

n_classes =2 
class_names = ["background","face"]

scales = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # anchorboxes for coco dataset
aspect_ratios = [[0.5, 1.0, 2.0],
                 [1.0/3.0, 0.5, 1.0, 2.0, 3.0],
                 [1.0/3.0, 0.5, 1.0, 2.0, 3.0],
                 [1.0/3.0, 0.5, 1.0, 2.0, 3.0],
                 [0.5, 1.0, 2.0],
                 [0.5, 1.0, 2.0]] # The anchor box aspect ratios used in the original SSD300
two_boxes_for_ar1 = True
limit_boxes = True # Whether or not you want to limit the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are scaled as in the original implementation
coords = 'centroids' # Whether the box coordinates to be used as targets for the model should be in the 'centroids' or 'minmax' format, see documentation
normalize_coords = True

det_model_path = "./"

# %% [markdown]
# ### Now, we have imported the model and its dependencies. The next thing is to import the dataset for the model to train on. For this, we are using the WIDER FACE dataset.
#
# #### To make the dataset available follow the steps given below.
#
#
# 1. Create a folder in your google drive for this project.
#
# 2. Download the train and test dataset files given in .zip format into your drive folder you created for the project in step-1.
#
# 3. Set the project path variable according to the folders you created to use for this project in your google drive.
#
#       `project_path = "/content/drive/My Drive/DLCP/"`
#
# 4. Now, as we mount the drive the images will be available to use for training and testing but in zip format.
#
# 5. So, lets extract the images from the zipfiles by using the code given of zipfile module.

# %%
## from google.colab import drive

# %%
##drive.mount('/content/drive')

# %%
project_path = "/content/drive/My Drive/Face Detection/"

# %%
train_images_path = project_path + 'WIDER_train.zip'
test_images_path = project_path + 'WIDER_val.zip'

# %%
import zipfile
archive = zipfile.ZipFile(train_images_path, 'r')
archive.extractall()

# %%
archive = zipfile.ZipFile(test_images_path, 'r')
archive.extractall()

# %% [markdown]
# ### Now, the images are available. The next thing we need is to get the labels for these images, so that we can use this information while training for detecting faces with the given model using transfer learning.
#
# #### Follow the below steps to get those labels available.
#
#
# Load the  '' `wider_train_small.npy`'' file given to check the information given about the dataset. In this file you can see the information about each image in the dataset in a list with following elemets:
#
#
#         1.   Image filename (str)
#         2.   Image filename (str)
#         3.   Image size (list) [height, width]
#         4.   List of bounding box co-ordinates and Class label (list) [[a,b,c,d], Class label, ...]
#
#         where,
#         a,b,c,d are the four co-ordinates of the bounding box
#         Class label is the position of object as mentioned in `class_names` list above.

# %%
##!pip install numpy==1.16.1
# Out:
# Collecting numpy==1.16.1
#   Downloading https://files.pythonhosted.org/packages/e0/b5/63b79fe426433fa1cd110eb04a94ec0c6967e56e5f57c98caf455a5fb6e2/numpy-1.16.1-cp27-cp27mu-manylinux1_x86_64.whl (17.0MB)
#      |████████████████████████████████| 17.0MB 2.8MB/s
# ERROR: fastai 0.7.0 has requirement torch<0.4, but you'll have torch 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: numpy
#   Found existing installation: numpy 1.16.3
#     Uninstalling numpy-1.16.3:
#       Successfully uninstalled numpy-1.16.3
# Successfully installed numpy-1.16.1

# %%
data = np.load('./wider_train_small.npy').item()

# %%
### Printed first element to check the above given information.

for key in data:
    print key
    print data[key]
    break
# Out:
# 52--Photographers/52_Photographers_photographertakingphoto_52_582.jpg
# ['WIDER_train/images/52--Photographers/52_Photographers_photographertakingphoto_52_582.jpg', 'WIDER_train/images/52--Photographers/52_Photographers_photographertakingphoto_52_582.jpg', [300, 300], [[21, 667, 9, 655], 1]]

# %% [markdown]
#  As we can see from the above output all the information mentioned above is there for all the images.

# %% [markdown]
# ### Now, load the files `wider_trian.npy` and `wider_val.npy`

# %%
train_data = 'wider_train_small.npy'
test_data = 'wider_val_small.npy'

x = np.load(train_data)

# %% [markdown]
# ### Now, call the imported model with the given parameters and freeze all the layers in the model with names not having ''`detection`'' word as prefix.
#
# As we are not training the model from scratch, we are freezing all the above layers in the model having only last few layers while training to update their weights according to the problem in hand. This is called as **Transfer Learning**.

# %%
# build the keras model
# this model is not retrained, we are doing it from scratch 

K.clear_session()
model, model_layer, img_input, predictor_sizes = mn_model(image_size=(img_height, img_width, img_channels), 
                                                                      n_classes = n_classes,
                                                                      min_scale = None, 
                                                                      max_scale = None, 
                                                                      scales = scales, 
                                                                      aspect_ratios_global = None, 
                                                                      aspect_ratios_per_layer = aspect_ratios, 
                                                                      two_boxes_for_ar1= two_boxes_for_ar1, 
                                                                      limit_boxes=limit_boxes, 
                                                                      variances= variances, 
                                                                      coords=coords, 
                                                                      normalize_coords=normalize_coords)
# Out:
# ====> Model Specific data
# ====> Height, Width, Channels : 512 512 3

# %% [markdown]
# #### Write code to freeze all the layers in the above model with names not having ''`detection`'' word as prefix.

# %%
#Freezing layers in the model which don't have 'dense' in their name
for layer in model.layers:
  if('detection' not in layer.name): #prefix detection to freeze layers which does not have dense
    #Freezing a layer
    layer.trainable = False

#Module to print colourful statements
from termcolor import colored

#Check which layers have been frozen 
for layer in model.layers:
  print (colored(layer.name, 'blue'))
  print (colored(layer.trainable, 'red'))
# Out:
# input_1
# False
# lambda1
# False
# lambda2
# False
# lambda3
# False
# conv1
# False
# conv1_bn
# False
# conv1_relu
# False
# conv_dw_1
# False
# conv_dw_1_bn
# False
# conv_dw_1_relu
# False
# conv_pw_1
# False
# conv_pw_1_bn
# False
# conv_pw_1_relu
# False
# conv_dw_2
# False
# conv_dw_2_bn
# False
# conv_dw_2_relu
# False
# conv_pw_2
# False
# conv_pw_2_bn
# False
# conv_pw_2_relu
# False
# conv_dw_3
# False
# conv_dw_3_bn
# False
# conv_dw_3_relu
# False
# conv_pw_3
# False
# conv_pw_3_bn
# False
# conv_pw_3_relu
# False
# conv_dw_4
# False
# conv_dw_4_bn
# False
# conv_dw_4_relu
# False
# conv_pw_4
# False
# conv_pw_4_bn
# False
# conv_pw_4_relu
# False
# conv_dw_5
# False
# conv_dw_5_bn
# False
# conv_dw_5_relu
# False
# conv_pw_5
# False
# conv_pw_5_bn
# False
# conv_pw_5_relu
# False
# conv_dw_6
# False
# conv_dw_6_bn
# False
# conv_dw_6_relu
# False
# conv_pw_6
# False
# conv_pw_6_bn
# False
# conv_pw_6_relu
# False
# conv_dw_7
# False
# conv_dw_7_bn
# False
# conv_dw_7_relu
# False
# conv_pw_7
# False
# conv_pw_7_bn
# False
# conv_pw_7_relu
# False
# conv_dw_8
# False
# conv_dw_8_bn
# False
# conv_dw_8_relu
# False
# conv_pw_8
# False
# conv_pw_8_bn
# False
# conv_pw_8_relu
# False
# conv_dw_9
# False
# conv_dw_9_bn
# False
# conv_dw_9_relu
# False
# conv_pw_9
# False
# conv_pw_9_bn
# False
# conv_pw_9_relu
# False
# conv_dw_10
# False
# conv_dw_10_bn
# False
# conv_dw_10_relu
# False
# conv_pw_10
# False
# conv_pw_10_bn
# False
# conv_pw_10_relu
# False
# conv_dw_11
# False
# conv_dw_11_bn
# False
# conv_dw_11_relu
# False
# conv_pw_11
# False
# conv_pw_11_bn
# False
# conv_pw_11_relu
# False
# conv_dw_12
# False
# conv_dw_12_bn
# False
# conv_dw_12_relu
# False
# conv_pw_12
# False
# conv_pw_12_bn
# False
# conv_pw_12_relu
# False
# conv_dw_13
# False
# conv_dw_13_bn
# False
# conv_dw_13_relu
# False
# conv_pw_13
# False
# conv_pw_13_bn
# False
# conv_pw_13_relu
# False
# detection_conv6_1
# True
# detection_conv6_1_bn
# True
# detection_conv6_1_nonlin
# True
# detection_conv6_2_conv_dw_1
# True
# detection_conv6_2_conv_dw_1_bn
# True
# detection_conv6_2_conv_dw_1_relu
# True
# detection_conv6_2_conv_pw_1
# True
# detection_conv6_2_conv_pw_1_bn
# True
# detection_conv6_2_conv_pw_1_relu
# True
# detection_conv7_1
# True
# detection_conv7_1_bn
# True
# detection_conv7_1_nonlin
# True
# detection_conv7_2_conv_dw_2
# True
# detection_conv7_2_conv_dw_2_bn
# True
# detection_conv7_2_conv_dw_2_relu
# True
# detection_conv7_2_conv_pw_2
# True
# detection_conv7_2_conv_pw_2_bn
# True
# detection_conv7_2_conv_pw_2_relu
# True
# detection_conv8_1
# True
# detection_conv8_1_bn
# True
# detection_conv8_1_nonlin
# True
# detection_conv8_2_conv_dw_3
# True
# detection_conv8_2_conv_dw_3_bn
# True
# detection_conv8_2_conv_dw_3_relu
# True
# detection_conv8_2_conv_pw_3
# True
# detection_conv8_2_conv_pw_3_bn
# True
# detection_conv8_2_conv_pw_3_relu
# True
# detection_conv9_1
# True
# detection_conv9_1_bn
# True
# detection_conv9_1_nonlin
# True
# detection_conv9_2_conv_dw_4
# True
# detection_conv9_2_conv_dw_4_bn
# True
# detection_conv9_2_conv_dw_4_relu
# True
# detection_conv9_2_conv_pw_4
# True
# detection_conv9_2_conv_pw_4_bn
# True
# detection_conv4_3_norm
# True
# detection_conv9_2_conv_pw_4_relu
# True
# detection_conv4_3_norm_mbox_conf_conv_dw_1
# True
# detection_fc7_mbox_conf_conv_dw_2
# True
# detection_conv6_2_mbox_conf_conv_dw_3
# True
# detection_conv7_2_mbox_conf_conv_dw_4
# True
# detection_conv8_2_mbox_conf_conv_dw_5
# True
# detection_conv9_2_mbox_conf_conv_dw_6
# True
# detection_conv4_3_norm_mbox_conf_conv_dw_1_bn
# True
# detection_fc7_mbox_conf_conv_dw_2_bn
# True
# detection_conv6_2_mbox_conf_conv_dw_3_bn
# True
# detection_conv7_2_mbox_conf_conv_dw_4_bn
# True
# detection_conv8_2_mbox_conf_conv_dw_5_bn
# True
# detection_conv9_2_mbox_conf_conv_dw_6_bn
# True
# detection_conv4_3_norm_mbox_loc_conv_dw_1
# True
# detection_fc7_mbox_loc_conv_dw_2
# True
# detection_conv6_2_mbox_loc_conv_dw_3
# True
# detection_conv7_2_mbox_loc_conv_dw_4
# True
# detection_conv8_2_mbox_loc_conv_dw_5
# True
# detection_conv9_2_mbox_loc_conv_dw_5
# True
# detection_conv4_3_norm_mbox_conf_conv_dw_1_relu
# True
# detection_fc7_mbox_conf_conv_dw_2_relu
# True
# detection_conv6_2_mbox_conf_conv_dw_3_relu
# True
# detection_conv7_2_mbox_conf_conv_dw_4_relu
# True
# detection_conv8_2_mbox_conf_conv_dw_5_relu
# True
# detection_conv9_2_mbox_conf_conv_dw_6_relu
# True
# detection_conv4_3_norm_mbox_loc_conv_dw_1_bn
# True
# detection_fc7_mbox_loc_conv_dw_2_bn
# True
# detection_conv6_2_mbox_loc_conv_dw_3_bn
# True
# detection_conv7_2_mbox_loc_conv_dw_4_bn
# True
# detection_conv8_2_mbox_loc_conv_dw_5_bn
# True
# detection_conv9_2_mbox_loc_conv_dw_5_bn
# True
# detection_conv4_3_norm_mbox_conf_conv_pw_1
# True
# detection_fc7_mbox_conf_conv_pw_2
# True
# detection_conv6_2_mbox_conf_conv_pw_3
# True
# detection_conv7_2_mbox_conf_conv_pw_4
# True
# detection_conv8_2_mbox_conf_conv_pw_5
# True
# detection_conv9_2_mbox_conf_conv_pw_6
# True
# detection_conv4_3_norm_mbox_loc_conv_dw_1_relu
# True
# detection_fc7_mbox_loc_conv_dw_2_relu
# True
# detection_conv6_2_mbox_loc_conv_dw_3_relu
# True
# detection_conv7_2_mbox_loc_conv_dw_4_relu
# True
# detection_conv8_2_mbox_loc_conv_dw_5_relu
# True
# detection_conv9_2_mbox_loc_conv_dw_5_relu
# True
# detection_conv4_3_norm_mbox_conf_conv_pw_1_bn
# True
# detection_fc7_mbox_conf_conv_pw_2_bn
# True
# detection_conv6_2_mbox_conf_conv_pw_3_bn
# True
# detection_conv7_2_mbox_conf_conv_pw_4_bn
# True
# detection_conv8_2_mbox_conf_conv_pw_5_bn
# True
# detection_conv9_2_mbox_conf_conv_pw_6_bn
# True
# detection_conv4_3_norm_mbox_loc_conv_pw_1
# True
# detection_fc7_mbox_loc_conv_pw_2
# True
# detection_conv6_2_mbox_loc_conv_pw_3
# True
# detection_conv7_2_mbox_loc_conv_pw_4
# True
# detection_conv8_2_mbox_loc_conv_pw_5
# True
# detection_conv9_2_mbox_loc_conv_pw_5
# True
# detection_conv4_3_norm_mbox_conf_conv_pw_1_relu
# True
# detection_fc7_mbox_conf_conv_pw_2_relu
# True
# detection_conv6_2_mbox_conf_conv_pw_3_relu
# True
# detection_conv7_2_mbox_conf_conv_pw_4_relu
# True
# detection_conv8_2_mbox_conf_conv_pw_5_relu
# True
# detection_conv9_2_mbox_conf_conv_pw_6_relu
# True
# detection_conv4_3_norm_mbox_loc_conv_pw_1_bn
# True
# detection_fc7_mbox_loc_conv_pw_2_bn
# True
# detection_conv6_2_mbox_loc_conv_pw_3_bn
# True
# detection_conv7_2_mbox_loc_conv_pw_4_bn
# True
# detection_conv8_2_mbox_loc_conv_pw_5_bn
# True
# detection_conv9_2_mbox_loc_conv_pw_5_bn
# True
# detection_conv4_3_norm_mbox_conf_reshape
# True
# detection_fc7_mbox_conf_reshape
# True
# detection_conv6_2_mbox_conf_reshape
# True
# detection_conv7_2_mbox_conf_reshape
# True
# detection_conv8_2_mbox_conf_reshape
# True
# detection_conv9_2_mbox_conf_reshape
# True
# detection_conv4_3_norm_mbox_loc_conv_pw_1_relu
# True
# detection_fc7_mbox_loc_conv_pw_2_relu
# True
# detection_conv6_2_mbox_loc_conv_pw_3_relu
# True
# detection_conv7_2_mbox_loc_conv_pw_4_relu
# True
# detection_conv8_2_mbox_loc_conv_pw_5_relu
# True
# detection_conv9_2_mbox_loc_conv_pw_5_relu
# True
# detection_conv4_3_norm_mbox_priorbox
# True
# detection_fc7_mbox_priorbox
# True
# detection_conv6_2_mbox_priorbox
# True
# detection_conv7_2_mbox_priorbox
# True
# detection_conv8_2_mbox_priorbox
# True
# detection_conv9_2_mbox_priorbox
# True
# detection_mbox_conf
# True
# detection_conv4_3_norm_mbox_loc_reshape
# True
# detection_fc7_mbox_loc_reshape
# True
# detection_conv6_2_mbox_loc_reshape
# True
# detection_conv7_2_mbox_loc_reshape
# True
# detection_conv8_2_mbox_loc_reshape
# True
# detection_conv9_2_mbox_loc_reshape
# True
# detection_conv4_3_norm_mbox_priorbox_reshape
# True
# detection_fc7_mbox_priorbox_reshape
# True
# detection_conv6_2_mbox_priorbox_reshape
# True
# detection_conv7_2_mbox_priorbox_reshape
# True
# detection_conv8_2_mbox_priorbox_reshape
# True
# detection_conv9_2_mbox_priorbox_reshape
# True
# detection_mbox_conf_softmax
# True
# detection_mbox_loc
# True
# detection_mbox_priorbox
# True
# detection_predictions
# True

# %% [markdown]
# ### After making the model ready for transfer learning, load the weights of the model given in file ''`mobilenet_1_0_224_tf.h5`''

# %%
#The pre-trained weights must exist in a folder in the current folder
model.load_weights('/content/drive/My Drive/Face Detection/mobilenet_1_0_224_tf.h5',by_name=True)

# %% [markdown]
# #### Using the functions given in the model, we are trying to divide the dataset into train and validation samples. Run the below code.

# %%
batch_size = 32
ssd_box_encoder = SSDBoxEncoder(img_height=img_height,
                                img_width=img_width,
                                n_classes=n_classes, 
                                predictor_sizes=predictor_sizes,
                                min_scale=None,
                                max_scale=None,
                                scales=scales,
                                aspect_ratios_global=None,
                                aspect_ratios_per_layer=aspect_ratios,
                                two_boxes_for_ar1=two_boxes_for_ar1,
                                limit_boxes=limit_boxes,
                                variances=variances,
                                pos_iou_threshold=0.5,
                                neg_iou_threshold=0.2,
                                coords=coords,
                                normalize_coords=normalize_coords)

train_dataset = BatchGenerator(images_path=train_data, 
                include_classes='all', 
                box_output_format = ['class_id', 'xmin', 'xmax', 'ymin', 'ymax'])

print ("==>TRAINING DATA")
print ("==> Parsing XML files ...")

train_dataset.parse_xml(
                  annotations_path=train_data,
                  image_set_path='None',
                  image_set='None',
                  classes = class_names, 
                  exclude_truncated=False,
                  exclude_difficult=False,
                  ret=False, 
                  debug = False)
print("==>Parsing XML Finished.")

print ("==>Generate training batches...")
train_generator = train_dataset.generate(
                 batch_size=batch_size,
                 train=True,
                 ssd_box_encoder=ssd_box_encoder,
                 equalize=True,
                 brightness=(0.5,2,0.5),
                 flip=0.5,
                 translate=((0, 20), (0, 30), 0.5),
                 scale=(0.75, 1.2, 0.5),
                 crop=False,
                 #random_crop = (img_height,img_width,1,3), 
                 random_crop=False,
                 resize=(img_height, img_width),
                 #resize=False,
                 gray=False,
                 limit_boxes=True,
                 include_thresh=0.4,
                 diagnostics=False)

print ("==>Training batch generation complete")

n_train_samples = train_dataset.get_n_samples()

print ("==>Total number of training samples = {}".format(n_train_samples))

# Now repeat above steps for validation data 

print ("==>VALIDATION")

val_dataset = BatchGenerator(images_path=test_data, include_classes='all', 
                box_output_format = ['class_id', 'xmin', 'xmax', 'ymin', 'ymax'])

print ("==> Parsing XML files ...")


val_dataset.parse_xml(
                  annotations_path=test_data,
                  image_set_path='None',
                  image_set='None',
                  classes = class_names, 
                  exclude_truncated=False,
                  exclude_difficult=False,
                  ret=False, 
                  debug = False)


print("==>Parsing XML Finished.")


print ("==>Generate training batches...")
val_generator = val_dataset.generate(
                 batch_size=batch_size,
                 train=True,
                 ssd_box_encoder=ssd_box_encoder,
                 equalize=False,
                 brightness=False,
                 flip=False,
                 translate=False,
                 scale=False,
                 crop=False,
                 #random_crop = (img_height,img_width,1,3), 
                 random_crop=False, 
                 resize=(img_height, img_width), 
                 #resize=False, 
                 gray=False,
                 limit_boxes=True,
                 include_thresh=0.4,
                 diagnostics=False)


print ("==>Training batch generation complete")

n_val_samples = val_dataset.get_n_samples()

print ("==>Total number of validation samples = {}".format(n_val_samples))
# Out:
# ==>TRAINING DATA
# ==> Parsing XML files ...
# ==>Parsing XML Finished.
# ==>Generate training batches...
# ==>Training batch generation complete
# ==>Total number of training samples = 128
# ==>VALIDATION
# ==> Parsing XML files ...
# ==>Parsing XML Finished.
# ==>Generate training batches...
# ==>Training batch generation complete
# ==>Total number of validation samples = 60

# %% [markdown]
# ### Now, lets setup things for training by initilaizing required variables like learning rate, epochs, optimizer and loss function(SSDLoss) to compile the model

# %%
# setting up training 

# batch_size and no.of epochs

batch_size = 16
num_epochs = 10

#Learning rate
base_lr = 0.002

# Optimizer
adam = Adam(lr=base_lr, beta_1=0.9, beta_2=0.999, epsilon=1e-6, decay = 0.0)

# Loss
ssd_loss = SSDLoss(neg_pos_ratio=2, n_neg_min=0, alpha=1.0, beta = 1.0)

# Compile
model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %% [markdown]
# ### Lets add early stopping and model checkpoint layers on validation loss with some patience values and using fit_generator function to train the model on data generated batch-by-batch by a Python generator, `train_generator` object as generator.
#
#
# We are using checkpoint to save the best model based on validation accuracy.

# %% [markdown]
# #### Write code for early_stopping and model_checkpoint layers. Using model.fit_generator train the model and save the best weight file.

# %%
det_model_path = "/content/drive/My Drive/Face Detection/FDModels/"

# %%
pwd
# Out:
# u'/content/drive/My Drive/Face Detection'

# %%
ls
# Out:
# dataset/                         Models/
# _DS_Store                        output_test/
# face_generator.py                predictor.py
# face_generator.pyc               ssd_box_encode_decode_utils.py
# FDModels/                        ssd_box_encode_decode_utils.pyc
# _gitattributes                   ssd_mobilenet_face_epoch_25_loss0.0916.h5
# _gitignore                       wider_extract.py
# keras_layer_AnchorBoxes.py       WIDER_train/
# keras_layer_AnchorBoxes.pyc      wider_train_small.npy
# keras_layer_L2Normalization.py   wider_train_v1.npy
# keras_layer_L2Normalization.pyc  WIDER_train.zip
# keras_ssd_loss.py                WIDER_val/
# keras_ssd_loss.pyc               wider_val_small.npy
# mn_model.py                      wider_val_v1.npy
# mn_model.pyc                     WIDER_val.zip
# mobilenet_1_0_224_tf.h5

# %%
def scheduler(epoch):
  if epoch%10==0 and epoch!=0:
    lr = K.get_value(model.optimizer.lr)
    K.set_value(model.optimizer.lr, lr*.95)
    print("lr changed to {}".format(lr*.95))
  else: 
    print("lr remains {}".format(K.get_value(model.optimizer.lr)))

  return K.get_value(model.optimizer.lr)

lr_schedule = LearningRateScheduler(scheduler)

plateau = ReduceLROnPlateau(monitor='val_loss', factor = 0.3, patience =4, epsilon=0.001, cooldown=0)
tensorboard = TensorBoard(log_dir='./logs/trial1/', histogram_freq=1, batch_size=16, write_graph=True, write_grads=True, 
                          write_images=True, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None)
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=100)
model_checkpoint =  ModelCheckpoint(det_model_path + 'ssd_mobilenet_face_epoch_{epoch:02d}_loss{val_loss:.4f}.h5',
                                                           monitor='val_loss',
                                                           verbose=1,
                                                           save_best_only=True,
                                                           save_weights_only=True,
                                                           mode='auto',
                                                           period=1)


history = model.fit_generator(generator = train_generator,
                              steps_per_epoch = ceil(n_train_samples/batch_size)*2,
                              epochs = num_epochs,
                              callbacks = [model_checkpoint, lr_schedule, early_stopping],                      
                              validation_data = val_generator,
                              validation_steps = ceil(n_val_samples/batch_size))

model.save_weights(det_model_path + 'ssd_mobilenet_weights_epoch_{}.h5'.format(num_epochs))

print ("model and weight files saved at : " + det_model_path)
# Out:
# Epoch 1/10
# lr remains 0.00200000009499
# 16/16 [==============================] - 486s 30s/step - loss: 0.2565 - val_loss: 0.2859
#
# Epoch 00001: val_loss improved from inf to 0.28589, saving model to /content/drive/My Drive/Face Detection/FDModels/ssd_mobilenet_face_epoch_01_loss0.2859.h5
# Epoch 2/10
# lr remains 0.00200000009499
# 16/16 [==============================] - 459s 29s/step - loss: 0.2301 - val_loss: 0.2602
#
# Epoch 00002: val_loss improved from 0.28589 to 0.26023, saving model to /content/drive/My Drive/Face Detection/FDModels/ssd_mobilenet_face_epoch_02_loss0.2602.h5
# Epoch 3/10
# lr remains 0.00200000009499
# 16/16 [==============================] - 457s 29s/step - loss: 0.2242 - val_loss: 0.2352
#
# Epoch 00003: val_loss improved from 0.26023 to 0.23517, saving model to /content/drive/My Drive/Face Detection/FDModels/ssd_mobilenet_face_epoch_03_loss0.2352.h5
# Epoch 4/10
# lr remains 0.00200000009499
# 16/16 [==============================] - 453s 28s/step - loss: 0.2116 - val_loss: 0.2401
#
# Epoch 00004: val_loss did not improve from 0.23517
# Epoch 5/10
# lr remains 0.00200000009499
# 16/16 [==============================] - 453s 28s/step - loss: 0.2067 - val_loss: 0.2185
#
# Epoch 00005: val_loss improved from 0.23517 to 0.21853, saving model to /content/drive/My Drive/Face Detection/FDModels/ssd_mobilenet_face_epoch_05_loss0.2185.h5
# Epoch 6/10
# lr remains 0.00200000009499
# 16/16 [==============================] - 450s 28s/step - loss: 0.2059 - val_loss: 0.2324
#
# Epoch 00006: val_loss did not improve from 0.21853
# Epoch 7/10
# lr remains 0.00200000009499
# 16/16 [==============================] - 458s 29s/step - loss: 0.2058 - val_loss: 0.2126
#
# Epoch 00007: val_loss improved from 0.21853 to 0.21256, saving model to /content/drive/My Drive/Face Detection/FDModels/ssd_mobilenet_face_epoch_07_loss0.2126.h5
# Epoch 8/10
# lr remains 0.00200000009499
# 16/16 [==============================] - 454s 28s/step - loss: 0.2018 - val_loss: 0.2404
#
# Epoch 00008: val_loss did not improve from 0.21256
# Epoch 9/10
# lr remains 0.00200000009499
# 16/16 [==============================] - 458s 29s/step - loss: 0.2008 - val_loss: 0.2188
#
# Epoch 00009: val_loss did not improve from 0.21256
# Epoch 10/10
# lr remains 0.00200000009499
# 16/16 [==============================] - 449s 28s/step - loss: 0.2048 - val_loss: 0.2226
#
# Epoch 00010: val_loss did not improve from 0.21256
# model and weight files saved at : /content/drive/My Drive/Face Detection/FDModels/

# %% [markdown]
# ### Load the best saved model from above step and check predictions for test data using test_generator object to generate batches.

# %% [markdown]
# #### Write code in the below cell to load best saved model in the above step.

# %%
## Best Model 

## Epoch 00007: val_loss improved from 0.21853 to 0.21256, saving model to /content/drive/My Drive/Face Detection/FDModels/ssd_mobilenet_face_epoch_07_loss0.2126.h5

# %%
model_path = '/content/drive/My Drive/Face Detection/FDModels/'
model_name = 'ssd_mobilenet_face_epoch_07_loss0.2126.h5'

model.load_weights(model_path + model_name,  by_name= True)

# %% [markdown]
# ### Use the below function to plot the boundingbox in the test image to show the predictions.

# %%
def save_bb(path, filename, results, prediction=True):
  
  # print filename

  img = image.load_img(filename, target_size=(img_height, img_width))
  img = image.img_to_array(img)

  filename = filename.split("/")[-1]

  if(not prediction):
    filename = filename[:-4] + "_gt" + ".jpg"

  #fig,currentAxis = plt.subplots(1)
  currentAxis = plt.gca()

 # Get detections with confidence higher than 0.6.
  colors = plt.cm.hsv(np.linspace(0, 1, 25)).tolist()
  color_code = min(len(results), 16)
  print (colored("total number of bbs: %d" % len(results), "yellow"))
  for result in results:
    # Parse the outputs.

    if(prediction):
      det_label = result[0]
      det_conf = result[1]
      det_xmin = result[2]
      det_xmax = result[3]
      det_ymin = result[4]
      det_ymax = result[5]
    else :
      det_label = result[0]
      det_xmin = result[1]
      det_xmax = result[2]
      det_ymin = result[3]
      det_ymax = result[4]

    xmin = int(det_xmin)
    ymin = int(det_ymin)
    xmax = int(det_xmax)
    ymax = int(det_ymax)

    if(prediction):
      score = det_conf
    
    plt.imshow(img / 255.)
    
    label = int(int(det_label))
    label_name = class_names[label]
    # print label_name 
    # print label

    if(prediction):
      display_txt = '{:0.2f}'.format(score)
    else:
      display_txt = '{}'.format(label_name)

      
    # print (xmin, ymin, ymin, ymax)
    coords = (xmin, ymin), (xmax-xmin), (ymax-ymin)
    color_code = color_code-1 
    color = colors[color_code]
    currentAxis.add_patch(plt.Rectangle(*coords, fill=False, edgecolor=color, linewidth=2))
    currentAxis.text(xmin, ymin, display_txt, bbox={'facecolor':color, 'alpha':0.2})

  # y
  currentAxis.axes.get_yaxis().set_visible(False)
  # x
  currentAxis.axes.get_xaxis().set_visible(False)
  plt.savefig(path + filename, bbox_inches='tight')

  print ('saved' , path + filename)

  plt.clf()

# %% [markdown]
# #### Run the below code to create a folder with name output_test and get the predictions for the test images using model.predict()

# %%
# !mkdir output_test_Model

# %%
from keras.preprocessing import image
from matplotlib import pyplot as plt

test_size = 20
test_generator = val_dataset.generate(
                 batch_size=test_size,
                 train=False,
                 ssd_box_encoder=ssd_box_encoder,
                 equalize=False,
                 brightness=False,
                 flip=False,
                 translate=False,
                 scale=False,
                 crop=False,
                 #random_crop = (img_height,img_width,1,3), 
                 random_crop=False, 
                 resize=(img_height, img_width), 
                 #resize=False,
                 gray=False,
                 limit_boxes=True,
                 include_thresh=0.4,
                 diagnostics=False)

print (colored("done.", "green"))

print (colored("now predicting...", "yellow"))

_CONF = 0.60 
_IOU = 0.15

for i in range(test_size):
    X, y, filenames = next(test_generator)

    y_pred = model.predict(X)
    y_pred_decoded = decode_y2(y_pred,
                             confidence_thresh=_CONF,
                            iou_threshold=_IOU,
                            top_k='all',
                            input_coords=coords,
                            normalize_coords=normalize_coords,
                            img_height=img_height,
                            img_width=img_width)


    np.set_printoptions(suppress=True)

    save_bb("./output_test_Model/", filenames[i], y_pred_decoded[i])
    save_bb("./output_test_Model/", filenames[i], y[i], prediction=False)
# Out:
# done.
# now predicting...
# total number of bbs: 3
# ('saved', './output_test_Model/38_Tennis_Tennis_38_501.jpg')
# total number of bbs: 4
# ('saved', './output_test_Model/38_Tennis_Tennis_38_501_gt.jpg')
# total number of bbs: 7
# ('saved', './output_test_Model/20_Family_Group_Family_Group_20_696.jpg')
# total number of bbs: 7
# ('saved', './output_test_Model/20_Family_Group_Family_Group_20_696_gt.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/47_Matador_Bullfighter_matadorbullfighting_47_236.jpg')
# total number of bbs: 27
# ('saved', './output_test_Model/47_Matador_Bullfighter_matadorbullfighting_47_236_gt.jpg')
# total number of bbs: 2
# ('saved', './output_test_Model/2_Demonstration_Political_Rally_2_219.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/2_Demonstration_Political_Rally_2_219_gt.jpg')
# total number of bbs: 2
# ('saved', './output_test_Model/2_Demonstration_Demonstration_Or_Protest_2_306.jpg')
# total number of bbs: 10
# ('saved', './output_test_Model/2_Demonstration_Demonstration_Or_Protest_2_306_gt.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/30_Surgeons_Surgeons_30_533.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/30_Surgeons_Surgeons_30_533_gt.jpg')
# total number of bbs: 2
# ('saved', './output_test_Model/2_Demonstration_Demonstration_Or_Protest_2_367.jpg')
# total number of bbs: 9
# ('saved', './output_test_Model/2_Demonstration_Demonstration_Or_Protest_2_367_gt.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/33_Running_Running_33_209.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/33_Running_Running_33_209_gt.jpg')
# total number of bbs: 4
# ('saved', './output_test_Model/35_Basketball_basketballgame_ball_35_998.jpg')
# total number of bbs: 26
# ('saved', './output_test_Model/35_Basketball_basketballgame_ball_35_998_gt.jpg')
# total number of bbs: 0
# ('saved', './output_test_Model/18_Concerts_Concerts_18_536.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/18_Concerts_Concerts_18_536_gt.jpg')
# total number of bbs: 0
# ('saved', './output_test_Model/33_Running_Running_33_475.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/33_Running_Running_33_475_gt.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/41_Swimming_Swimmer_41_376.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/41_Swimming_Swimmer_41_376_gt.jpg')
# total number of bbs: 0
# ('saved', './output_test_Model/44_Aerobics_Aerobics_44_184.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/44_Aerobics_Aerobics_44_184_gt.jpg')
# total number of bbs: 0
# ('saved', './output_test_Model/26_Soldier_Drilling_Soldiers_Drilling_26_393.jpg')
# total number of bbs: 5
# ('saved', './output_test_Model/26_Soldier_Drilling_Soldiers_Drilling_26_393_gt.jpg')
# total number of bbs: 7
# ('saved', './output_test_Model/12_Group_Large_Group_12_Group_Large_Group_12_448.jpg')
# total number of bbs: 5
# ('saved', './output_test_Model/12_Group_Large_Group_12_Group_Large_Group_12_448_gt.jpg')
# total number of bbs: 2
# ('saved', './output_test_Model/41_Swimming_Swimming_41_580.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/41_Swimming_Swimming_41_580_gt.jpg')
# total number of bbs: 0
# ('saved', './output_test_Model/33_Running_Running_33_475.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/33_Running_Running_33_475_gt.jpg')
# total number of bbs: 2
# ('saved', './output_test_Model/2_Demonstration_Demonstration_Or_Protest_2_306.jpg')
# total number of bbs: 10
# ('saved', './output_test_Model/2_Demonstration_Demonstration_Or_Protest_2_306_gt.jpg')
# total number of bbs: 2
# ('saved', './output_test_Model/57_Angler_peoplefishing_57_153.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/57_Angler_peoplefishing_57_153_gt.jpg')
# total number of bbs: 1
# ('saved', './output_test_Model/47_Matador_Bullfighter_matadorbullfighting_47_236.jpg')
# total number of bbs: 27
# ('saved', './output_test_Model/47_Matador_Bullfighter_matadorbullfighting_47_236_gt.jpg')

# %% [markdown]
# In the above step all the test images along with predictions are stored in output_test folder in this notebook environment. You can check the folder in Files section of the menu to left-side of screen in colab.
#
# Each test image is used for predictions and is stored as 2 files.
#
# one file is the original ground truth with <filename_gt.jpg>
# second file is the prediction of the model on the image. with <filename.jpg>

# %% [markdown]
# ### Visualize a test image to check predictions
#
#
# #### Write code to show images: Using cv2.imshow() or matplotlib show any 3 test images and their predictions.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2

# %%
## Groud Truth - Image 1

# %%
img = cv2.imread('/content/drive/My Drive/Face Detection/output_test_Model/12_Group_Large_Group_12_Group_Large_Group_12_448_gt.jpg')
plt.imshow(img)
plt.show()

# %%
## Prediction- Image 1

# %%
img = cv2.imread('/content/drive/My Drive/Face Detection/output_test_Model/12_Group_Large_Group_12_Group_Large_Group_12_448.jpg')
plt.imshow(img)
plt.show()

# %%
## Ground Truth - Image 2

# %%
img = cv2.imread('/content/drive/My Drive/Face Detection/output_test_Model/18_Concerts_Concerts_18_102_gt.jpg')
plt.imshow(img)
plt.show()

# %%
## Prediction - Image 2

# %%
img = cv2.imread('/content/drive/My Drive/Face Detection/output_test_Model/18_Concerts_Concerts_18_102.jpg')
plt.imshow(img)
plt.show()

# %%
## Ground Truth- Image 3

# %%
img = cv2.imread('/content/drive/My Drive/Face Detection/output_test_Model/57_Angler_peoplefishing_57_153_gt.jpg')
plt.imshow(img)
plt.show()

# %%
## Prediction - Image 3

# %%
img = cv2.imread('/content/drive/My Drive/Face Detection/output_test_Model/57_Angler_peoplefishing_57_153.jpg')
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Observation on the Predictions

# %%
## Observation 

## 1. First picture prediction was more accurate
## 2. Second one is the wrong one
## 3. Third one has predicted 2 faces but still the True Positive was correct
